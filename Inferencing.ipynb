# %%
from inference.interface_class import ObjectDetectionModel

# %%
predictor = ObjectDetectionModel(model_checkpoint_path='training/models_weights/resnet50_csv_1200_10.h5',
                                 test_data_path='test_retina_format.csv', classes_path='classes.csv')
# Out:
# /Users/diegoaguado/.local/lib/python3.5/site-packages/Keras-2.1.2-py3.5.egg/keras/models.py:252: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
predictor.generate_image_and_prediction()
